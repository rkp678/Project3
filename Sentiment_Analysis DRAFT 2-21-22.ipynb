# %% [markdown]
# # FINAL PROJECT

# %% [markdown]
# ## Sentiment Analysis on Cryptocurrency vs. Open Banking vs. Banking

# %% [markdown]
# ### Data Prep/Cleanup for Sentiment Analysis

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
from pathlib import Path

# For Sentiment Analysis
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# %matplotlib inline

# For Tokenizing
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# For NER
import spacy
from spacy import displacy

# For Ngrams
from collections import Counter
from nltk import ngrams
from nltk.util import ngrams

# For Word Clouds
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [10.0, 5.0]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Read api key environment variable
load_dotenv()

api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Part 1
# Fetch the cryptocurrency news articles
crypto_news = newsapi.get_everything(
    q="cryptocurrency",
    language="en"
)

# Show the total number of news
crypto_news["totalResults"]
# Out:
# 10407

# %%
# Create the Crypto sentiment scores DataFrame
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)

# %%
crypto_df = create_df(crypto_news["articles"], "en")
crypto_df.head()
# Out:
#                                                title  \
# 0  Robinhood opens cryptocurrency wallet to beta ...
# 1  Gibraltar Could Launch the World’s First Crypt...
# 2  The International Monetary Fund tells El Salva...
# 3  The DOJ's $3.6B Seizure Shows How Hard It Is t...
# 4               Is the Crypto Bubble Going to Burst?
#
#                                          description  \
# 0  Back in September\r\n, Robinhood announced pla...
# 1  “The Rock” hopes a new stock exchange will att...
# 2  The International Monetary Fund’s executive di...
# 3  A couple allegedly used a “laundry list” of te...
# 4  Even if you aren’t paying attention to Bitcoin...
#
#                                                 text        date language
# 0  Back in September\r\n, Robinhood announced pla...  2022-01-21       en
# 1  British entrepreneur and financier Richard ODe...  2022-01-26       en
# 2  El Salvador introduced Bitcoin as a legal tend...  2022-01-25       en
# 3  On Tuesday, Ilya Lichtenstein and Heather Morg...  2022-02-09       en
# 4  Even if you arent paying attention to Bitcoin ...  2022-02-09       en

# %%
# Describe the Crypto Sentiment
# First get the sentiment calculation
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Second get the Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in crypto_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Crypto DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
crypto_df = crypto_df.join(title_sentiment_df).join(text_sentiment_df)

crypto_df.head()
# Out:
#                                                title  \
# 0  Robinhood opens cryptocurrency wallet to beta ...
# 1  Gibraltar Could Launch the World’s First Crypt...
# 2  The International Monetary Fund tells El Salva...
# 3  The DOJ's $3.6B Seizure Shows How Hard It Is t...
# 4               Is the Crypto Bubble Going to Burst?
#
#                                          description  \
# 0  Back in September\r\n, Robinhood announced pla...
# 1  “The Rock” hopes a new stock exchange will att...
# 2  The International Monetary Fund’s executive di...
# 3  A couple allegedly used a “laundry list” of te...
# 4  Even if you aren’t paying attention to Bitcoin...
#
#                                                 text        date language  \
# 0  Back in September\r\n, Robinhood announced pla...  2022-01-21       en
# 1  British entrepreneur and financier Richard ODe...  2022-01-26       en
# 2  El Salvador introduced Bitcoin as a legal tend...  2022-01-25       en
# 3  On Tuesday, Ilya Lichtenstein and Heather Morg...  2022-02-09       en
# 4  Even if you arent paying attention to Bitcoin ...  2022-02-09       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000      0.000           0         0.0772
# 1          0.0000      0.000      1.000      0.000           0         0.6808
# 2          0.1280      0.103      0.897      0.000           1         0.3182
# 3         -0.1027      0.000      0.887      0.113          -1        -0.7650
# 4          0.0000      0.000      1.000      0.000           0         0.5859
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.038     0.962     0.000          1
# 1     0.185     0.815     0.000          1
# 2     0.105     0.895     0.000          1
# 3     0.048     0.736     0.216         -1
# 4     0.124     0.876     0.000          1

# %% [raw]
# # Now to analyze the results:
# crypto_df.plot(
#     y=["title_sent", "text_sent"],
#     kind="bar",
#     title="News Title and Text Sentiment Comparison",
#     figsize=(10, 8),
#     grid=True,
# )

# %% [raw]
# # Get Stats on Crypto Dataframe
# crypto_df.describe()

# %%
# Part 2
# Fetch the open banking news articles
openbanking_news = newsapi.get_everything(
    q="open banking",
    language="en"
)

# Show the total number of news
openbanking_news["totalResults"]
# Out:
# 2757

# %%
# Create the Open Banking sentiment scores DataFrame
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)

# %%
openbanking_df = create_df(openbanking_news["articles"], "en")
openbanking_df.head()
# Out:
#                                                title  \
# 0  Indian shares open lower as IT, banks weigh - ...
# 1  Finicity co-founder talks open banking, fintec...
# 2  Plaid's Cognito deal helps it plan ahead for U...
# 3  Relationship banking can offer special perks, ...
# 4  Spruce banking review: Banking platform with c...
#
#                                          description  \
# 0  Indian shares edged lower on Friday, pressured...
# 1  Finicity CEO Steve Smith talks about how socia...
# 2  Open-banking provider Plaid has acquired Cogni...
# 3  Banks use relationship banking to build relati...
# 4  H&R Block has a new financial technology platf...
#
#                                                 text        date language
# 0  BENGALURU, Feb 18 (Reuters) - Indian shares ed...  2022-02-18       en
# 1  Although the UK pioneered open-\r\nbanking reg...  2022-02-04       en
# 2  The news: The \r\nopen-banking provider Plaid ...  2022-01-21       en
# 3  Relationship banking is a term you'll frequent...  2022-02-04       en
# 4  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en

# %%
# Describe the Open Banking Sentiment
# First get the sentiment calculation
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Second get the Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in openbanking_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Open Banking DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
openbanking_df = openbanking_df.join(title_sentiment_df).join(text_sentiment_df)

openbanking_df.head()
# Out:
#                                                title  \
# 0  Indian shares open lower as IT, banks weigh - ...
# 1  Finicity co-founder talks open banking, fintec...
# 2  Plaid's Cognito deal helps it plan ahead for U...
# 3  Relationship banking can offer special perks, ...
# 4  Spruce banking review: Banking platform with c...
#
#                                          description  \
# 0  Indian shares edged lower on Friday, pressured...
# 1  Finicity CEO Steve Smith talks about how socia...
# 2  Open-banking provider Plaid has acquired Cogni...
# 3  Banks use relationship banking to build relati...
# 4  H&R Block has a new financial technology platf...
#
#                                                 text        date language  \
# 0  BENGALURU, Feb 18 (Reuters) - Indian shares ed...  2022-02-18       en
# 1  Although the UK pioneered open-\r\nbanking reg...  2022-02-04       en
# 2  The news: The \r\nopen-banking provider Plaid ...  2022-01-21       en
# 3  Relationship banking is a term you'll frequent...  2022-02-04       en
# 4  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.177      0.645      0.177           0         0.1779
# 1          0.5106      0.292      0.708      0.000           1         0.6705
# 2          0.3818      0.206      0.794      0.000           1         0.5859
# 3          0.4939      0.208      0.792      0.000           1         0.4588
# 4          0.4767      0.220      0.780      0.000           1         0.8360
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.127     0.765     0.108          1
# 1     0.151     0.849     0.000          1
# 2     0.156     0.844     0.000          1
# 3     0.091     0.909     0.000          1
# 4     0.268     0.732     0.000          1

# %% [raw]
# # Now to analyze the results:
# openbanking_df.plot(
#     y=["title_sent", "text_sent"],
#     kind="bar",
#     title="News Title and Text Sentiment Comparison",
#     figsize=(10, 8),
#     grid=True,
# )

# %% [raw]
# # Get Stats on Open Banking Dataframe
# openbanking_df.describe()

# %%
# Part 3
# Fetch the banking news articles
banking_news = newsapi.get_everything(
    q="banking",
    language="en"
)

# Show the total number of news
banking_news["totalResults"]
# Out:
# 13428

# %%
# Create the Banking sentiment scores DataFrame
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)

# %%
banking_df = create_df(banking_news["articles"], "en")
banking_df.head()
# Out:
#                                                title  \
# 0                     The Banking CMO Report Preview
# 1  Spruce banking review: Banking platform with c...
# 2  India shares gain on energy, banking boost - R...
# 3    LIVE MARKETS Banking on banks in 2022 - Reuters
# 4  Australian shares weighed down by banking, hea...
#
#                                          description  \
# 0  Get an exclusive preview of the Banking CMO Re...
# 1  H&R Block has a new financial technology platf...
# 2  Indian shares rose on Friday, lifted by energy...
# 3  Welcome to the home for real-time coverage of ...
# 4  Australian shares slipped on Monday, as losses...
#
#                                                 text        date language
# 0  Our Banking CMO Report synthesizes interviews ...  2022-02-08       en
# 1  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en
# 2  BENGALURU, Jan 28 (Reuters) - Indian shares ro...  2022-01-28       en
# 3  Jan 25 - Welcome to the home for real-time cov...  2022-01-25       en
# 4  Feb 7 (Reuters) - Australian shares slipped on...  2022-02-07       en

# %%
# Describe the Banking Sentiment
# First get the sentiment calculation
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Second get the Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in banking_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Open Banking DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
banking_df = banking_df.join(title_sentiment_df).join(text_sentiment_df)

banking_df.head()
# Out:
#                                                title  \
# 0                     The Banking CMO Report Preview
# 1  Spruce banking review: Banking platform with c...
# 2  India shares gain on energy, banking boost - R...
# 3    LIVE MARKETS Banking on banks in 2022 - Reuters
# 4  Australian shares weighed down by banking, hea...
#
#                                          description  \
# 0  Get an exclusive preview of the Banking CMO Re...
# 1  H&R Block has a new financial technology platf...
# 2  Indian shares rose on Friday, lifted by energy...
# 3  Welcome to the home for real-time coverage of ...
# 4  Australian shares slipped on Monday, as losses...
#
#                                                 text        date language  \
# 0  Our Banking CMO Report synthesizes interviews ...  2022-02-08       en
# 1  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en
# 2  BENGALURU, Jan 28 (Reuters) - Indian shares ro...  2022-01-28       en
# 3  Jan 25 - Welcome to the home for real-time cov...  2022-01-25       en
# 4  Feb 7 (Reuters) - Australian shares slipped on...  2022-02-07       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000        0.0           0         0.7620
# 1          0.4767      0.220      0.780        0.0           1         0.8360
# 2          0.8555      0.722      0.278        0.0           1         0.7650
# 3          0.0000      0.000      1.000        0.0           0         0.6369
# 4          0.2960      0.216      0.784        0.0           1         0.6808
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.191     0.809     0.000          1
# 1     0.268     0.732     0.000          1
# 2     0.213     0.787     0.000          1
# 3     0.144     0.856     0.000          1
# 4     0.227     0.707     0.066          1

# %% [markdown]
# ### Sentiment Analysis

# %%
# Analyze Crypto Results:
crypto_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparison",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparison'}>

# %%
# Get Stats on Crypto Dataframe
crypto_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean         0.072060   0.078450   0.887900   0.033650    0.200000
# std          0.232018   0.119523   0.120482   0.076078    0.695852
# min         -0.340000   0.000000   0.656000   0.000000   -1.000000
# 25%          0.000000   0.000000   0.807000   0.000000    0.000000
# 50%          0.000000   0.000000   0.892000   0.000000    0.000000
# 75%          0.109025   0.189000   1.000000   0.000000    1.000000
# max          0.636900   0.344000   1.000000   0.286000    1.000000
#
#        text_compound   text_pos   text_neu  text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.00000  20.000000
# mean        0.116105   0.081450   0.875100   0.04345   0.200000
# std         0.428887   0.054884   0.073269   0.06401   0.951453
# min        -0.765000   0.000000   0.729000   0.00000  -1.000000
# 25%        -0.225725   0.043500   0.833250   0.00000  -1.000000
# 50%         0.197700   0.077500   0.885500   0.00000   1.000000
# 75%         0.447800   0.124750   0.922250   0.08750   1.000000
# max         0.680800   0.185000   1.000000   0.21600   1.000000

# %%
# Analyze Open Banking Results:
openbanking_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparison",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparison'}>

# %%
# Get Stats on Open Banking Dataframe
openbanking_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean         0.055055   0.094450   0.854400   0.051100    0.050000
# std          0.300924   0.133068   0.164306   0.092365    0.686333
# min         -0.440400   0.000000   0.541000   0.000000   -1.000000
# 25%          0.000000   0.000000   0.744000   0.000000    0.000000
# 50%          0.000000   0.000000   0.920000   0.000000    0.000000
# 75%          0.095450   0.184250   1.000000   0.040000    0.250000
# max          0.624900   0.459000   1.000000   0.244000    1.000000
#
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.000000   20.00000
# mean        0.224480   0.084400   0.887450   0.028100    0.65000
# std         0.430340   0.074977   0.078679   0.060459    0.67082
# min        -0.812600   0.000000   0.732000   0.000000   -1.00000
# 25%         0.057900   0.028500   0.843500   0.000000    0.75000
# 50%         0.236950   0.066000   0.904000   0.000000    1.00000
# 75%         0.547425   0.144250   0.939250   0.009750    1.00000
# max         0.836000   0.268000   1.000000   0.215000    1.00000

# %%
# Analyze Banking Results:
banking_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparison",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparison'}>

# %%
# Get Stats on Banking Dataframe
banking_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000   20.00000    20.00000
# mean         0.086860   0.129000   0.798000    0.07295     0.15000
# std          0.381627   0.185297   0.202395    0.13677     0.74516
# min         -0.612400   0.000000   0.278000    0.00000    -1.00000
# 25%          0.000000   0.000000   0.644500    0.00000     0.00000
# 50%          0.000000   0.000000   0.789000    0.00000     0.00000
# 75%          0.334100   0.208500   1.000000    0.04425     1.00000
# max          0.855500   0.722000   1.000000    0.41200     1.00000
#
#        text_compound   text_pos  text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.00000  20.000000  20.000000
# mean        0.355640   0.123700   0.83960   0.036750   0.600000
# std         0.432807   0.079698   0.08382   0.052773   0.753937
# min        -0.718400   0.000000   0.70700   0.000000  -1.000000
# 25%         0.077025   0.072750   0.78300   0.000000   0.750000
# 50%         0.517050   0.135500   0.83250   0.000000   1.000000
# 75%         0.694375   0.169250   0.90225   0.070250   1.000000
# max         0.836000   0.268000   1.00000   0.176000   1.000000

# %% [markdown]
# ### Sentiment Analysis Conclusions:
#
# Q: Which concept (Cryptocurrency, Open Banking, or Banking) had the highest mean positive score?
#
# A:
#
# Q: Which concept had the highest compound score?
#
# A:
#
# Q. Which concept had the highest positive score?
#
# A:

# %% [markdown]
# ## Natural Language Processing (Cryptocurrency vs. Open Banking vs. Banking)

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Cryptocurrency News
article = crypto_news
print(article)
# Out:
# {'status': 'ok', 'totalResults': 10407, 'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Igor Bonifacic', 'title': 'Robinhood opens cryptocurrency wallet to beta testers', 'description': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availability ahead of a full-scale release. If you joined the wait…', 'url': 'https://www.engadget.com/robinhood-cryptocurrency-wallet-beta-225721593.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-09/5035fef0-1bd6-11ec-b7e5-a610838e0b98', 'publishedAt': '2022-01-21T22:57:21Z', 'content': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars]'}, {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Gian M. Volpicelli', 'title': 'Gibraltar Could Launch the World’s First Crypto Stock Exchange', 'description': '“The Rock” hopes a new stock exchange will attract crypto millionaires who want to avoid hefty taxes.', 'url': 'https://www.wired.com/story/gibraltar-crypto-exchange/', 'urlToImage': 'https://media.wired.com/photos/61f0b4bf03f9ae99229f47d4/191:100/w_1280,c_limit/Business_Gibraltar-1208348908.jpg', 'publishedAt': '2022-01-26T12:00:00Z', 'content': 'British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Mitchell Clark', 'title': 'The International Monetary Fund tells El Salvador it shouldn’t use Bitcoin as legal tender', 'description': 'The International Monetary Fund’s executive directors have recommended to El Salvador that it should narrow the scope of its Bitcoin law, making it so that the cryptocurrency is no longer legal tender in the country.', 'url': 'https://www.theverge.com/2022/1/25/22901374/el-salvador-bitcoin-international-monetary-fund-crypto', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg', 'publishedAt': '2022-01-25T22:11:14Z', 'content': 'El Salvador introduced Bitcoin as a legal tender alongside the US dollar in 2021. | Illustration by Alex Castro / The Verge\r\n\n \n\n The International Monetary Fund’s executive board has recommended El … [+2691 chars]'}, {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Andy Greenberg', 'title': "The DOJ's $3.6B Seizure Shows How Hard It Is to Launder Crypto", 'description': "A couple allegedly used a “laundry list” of technical measures to cover their tracks. It didn't matter.", 'url': 'https://www.wired.com/story/bitcoin-seizure-record-doj-crypto-tracing-monero/', 'urlToImage': 'https://media.wired.com/photos/620436c9d88b0a9fa5094b52/191:100/w_1280,c_limit/Security-Crypto-Tracing-522019766.jpg', 'publishedAt': '2022-02-09T23:16:59Z', 'content': 'On Tuesday, Ilya Lichtenstein and Heather Morgan were arrested in New York and accused of laundering a record $4.5 billion dollars worth of stolen cryptocurrency. In the 24 hours since, the cybersecu… [+4297 chars]'}, {'source': {'id': None, 'name': 'Lifehacker.com'}, 'author': 'Jeff Somers', 'title': 'Is the Crypto Bubble Going to Burst?', 'description': 'Even if you aren’t paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 trillion last year to about $1.5 trillion in a matter of days…', 'url': 'https://lifehacker.com/is-the-crypto-bubble-going-to-burst-1848475768', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f ...

# %%
# Open Banking News
article2 = openbanking_news
print(article2)
# Out:
# {'status': 'ok', 'totalResults': 2757, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': None, 'title': 'Indian shares open lower as IT, banks weigh - Reuters India', 'description': 'Indian shares edged lower on Friday, pressured by IT and banking stocks, with investors focused on the East-West standoff over Ukraine, which has roiled markets this week.', 'url': 'https://www.reuters.com/world/india/indian-shares-open-lower-it-banks-weigh-2022-02-18/', 'urlToImage': 'https://www.reuters.com/resizer/1o3yBGdN4NLOe5wvYM1EltN1alM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EFGMTS3Y4JPKJN7YTA3AH3IKVE.jpg', 'publishedAt': '2022-02-18T04:05:00Z', 'content': 'BENGALURU, Feb 18 (Reuters) - Indian shares edged lower on Friday, pressured by IT and banking stocks, with investors focused on the East-West standoff over Ukraine, which has roiled markets this wee… [+874 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'insider@insider.com (Tyler Van Dyke)', 'title': 'Finicity co-founder talks open banking, fintech trust, and web3', 'description': 'Finicity CEO Steve Smith talks about how social media companies can build financial trust and what open banking can do for web3.', 'url': 'https://www.businessinsider.com/interview-with-finicity-ceo-steve-smith-on-open-banking-2022-2', 'urlToImage': 'https://i.insider.com/61fd3ce08a52640019fe3fe6?width=1200&format=jpeg', 'publishedAt': '2022-02-04T14:43:00Z', 'content': 'Although the UK\xa0pioneered\xa0open-\r\nbanking regulations (and popularized the term),\xa0Finicity\xa0CEO Steve Smith contends that the US has long been the engine of innovation driving the space forward.\r\nIn a … [+2619 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'insider@insider.com (Tom Auchterlonie)', 'title': "Plaid's Cognito deal helps it plan ahead for US open banking", 'description': 'Open-banking provider Plaid has acquired Cognito, a fintech that offers identity verification and compliance solutions.', 'url': 'https://www.businessinsider.com/plaid-acquires-cognito-identity-verification-compliance-fintech-2022-1', 'urlToImage': 'https://i.insider.com/61eacea62b43ff00185dfce3?width=1200&format=jpeg', 'publishedAt': '2022-01-21T15:32:00Z', 'content': 'The news:\xa0The \r\nopen-banking provider\xa0Plaid\xa0has\r\n\xa0acquired\r\n\xa0Cognito, a fintech that offers identity verification and compliance solutions.\r\nInsider Intelligence\r\nMore on this:\xa0In a blog post announc… [+3132 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'sacevedo@insider.com (Sophia Acevedo)', 'title': "Relationship banking can offer special perks, but you'll have to open several bank products. Is it worth it?", 'description': 'Banks use relationship banking to build relationships with customers. If you open several bank accounts, a bank may offer better rates or waive fees.', 'url': 'https://www.businessinsider.com/personal-finance/relationship-banking', 'urlToImage': 'https://i.insider.com/61fd43ac8a52640019fe419d?width=1200&format=jpeg', 'publishedAt': '2022-02-04T19:46:32Z', 'content': "Relationship banking is a term you'll frequently find in many brick-and-mortar banks or national banks. If you're looking at the interest rates of a savings account, you might see relationship rates … [+3055 chars]"}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'sacevedo@insider.com (Sophia Acevedo)', 'title': 'Spruce banking review: Banking platform with cash-back rewards and early direct deposit', 'description': 'H&R Block has a new financial technology platform named Spruce. Spruce has a Savings and Spending account with no monthly fees.', 'url': 'https://www.businessinsider.com/personal-finance/spruce-banking-review', 'urlToImage': 'https://i.insider.com/61e9da82f6297c00198f62bc?width=1200&format=jpeg', 'publishedAt': '2022-01-21T23:14:01Z', ...

# %%
# Banking News
article3 = banking_news
print(article3)
# Out:
# {'status': 'ok', 'totalResults': 13428, 'articles': [{'source': {'id': None, 'name': 'Insiderintelligence.com'}, 'author': 'insider@insider.com (Insider Intelligence)', 'title': 'The Banking CMO Report Preview', 'description': "Get an exclusive preview of the Banking CMO Report and to start receiving our Financial Services newsletter, Insider Intelligence Daily, which covers today's most important trends in banking, fintech, and payments.", 'url': 'https://www.insiderintelligence.com/resources/banking-cmo-preview-2021/', 'urlToImage': 'https://www.insiderintelligence.com/static/II_White_On_Black-855f55175b03be1ac1344daa89edbc4f.png', 'publishedAt': '2022-02-08T22:04:00Z', 'content': 'Our Banking CMO Report synthesizes interviews with 10 CMOs at some of the largest and most innovative banks, credit unions, and neobanks in the US and Canada.\r\nThrough our exclusive interviews, we pr… [+468 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'sacevedo@insider.com (Sophia Acevedo)', 'title': 'Spruce banking review: Banking platform with cash-back rewards and early direct deposit', 'description': 'H&R Block has a new financial technology platform named Spruce. Spruce has a Savings and Spending account with no monthly fees.', 'url': 'https://www.businessinsider.com/personal-finance/spruce-banking-review', 'urlToImage': 'https://i.insider.com/61e9da82f6297c00198f62bc?width=1200&format=jpeg', 'publishedAt': '2022-01-21T23:14:01Z', 'content': "The bottom line:Spruce is a solid \r\nmobile banking platform that doesn't charge monthly fees. Its accounts come with several special perks like cash-back rewards and early direct deposit. You'll want… [+3376 chars]"}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': None, 'title': 'India shares gain on energy, banking boost - Reuters', 'description': 'Indian shares rose on Friday, lifted by energy and banking stocks amid strong earnings momentum, while a slight rebound in global markets also aided investor sentiment.', 'url': 'https://www.reuters.com/world/india/india-shares-gain-energy-banking-boost-2022-01-28/', 'urlToImage': 'https://www.reuters.com/resizer/1o3yBGdN4NLOe5wvYM1EltN1alM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EFGMTS3Y4JPKJN7YTA3AH3IKVE.jpg', 'publishedAt': '2022-01-28T04:29:00Z', 'content': 'BENGALURU, Jan 28 (Reuters) - Indian shares rose on Friday, lifted by energy and banking stocks amid strong earnings momentum, while a slight rebound in global markets also aided investor sentiment.\r… [+1061 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': None, 'title': 'LIVE MARKETS Banking on banks in 2022 - Reuters', 'description': 'Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at <a href="mailto:markets.research@thomsonreuters.com" target="_blank">markets.research@thomsonreuters.com</a>', 'url': 'https://www.reuters.com/markets/asia/live-markets-banking-banks-2022-2022-01-25/', 'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=69', 'publishedAt': '2022-01-25T17:54:00Z', 'content': 'Jan 25 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nBANKING ON BANKS IN 202… [+13700 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': None, 'title': 'Australian shares weighed down by banking, healthcare stocks - Reuters', 'description': 'Australian shares slipped on Monday, as losses in the banking and healthcare sectors offset gains made by energy and mining firms, while travel stocks gained as the country geared up to reopen its borders to vaccinated tourists later in the month.', 'url': 'https://www.reuters.com/markets/stocks/australian-shares-weighed-down-by-banking-healthcare-stocks-2022-02-07/', 'urlToImage': 'https://www.re ...

# %%
# Complete the tokenizer function - Cryptocurrency
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    
    # NEED TO FIX STOPWORDS
    # Remove the stopwords 
    # words = list(filter(lambda t: t.lower() not in stop, words))
   
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# Create a new tokens column for Cryptocurrency
crypto_df["tokens"] = crypto_df.text.apply(tokenizer)
crypto_df.head()
# Out:
#                                                title  \
# 0  Robinhood opens cryptocurrency wallet to beta ...
# 1  Gibraltar Could Launch the World’s First Crypt...
# 2  The International Monetary Fund tells El Salva...
# 3  The DOJ's $3.6B Seizure Shows How Hard It Is t...
# 4               Is the Crypto Bubble Going to Burst?
#
#                                          description  \
# 0  Back in September\r\n, Robinhood announced pla...
# 1  “The Rock” hopes a new stock exchange will att...
# 2  The International Monetary Fund’s executive di...
# 3  A couple allegedly used a “laundry list” of te...
# 4  Even if you aren’t paying attention to Bitcoin...
#
#                                                 text        date language  \
# 0  Back in September\r\n, Robinhood announced pla...  2022-01-21       en
# 1  British entrepreneur and financier Richard ODe...  2022-01-26       en
# 2  El Salvador introduced Bitcoin as a legal tend...  2022-01-25       en
# 3  On Tuesday, Ilya Lichtenstein and Heather Morg...  2022-02-09       en
# 4  Even if you arent paying attention to Bitcoin ...  2022-02-09       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000      0.000           0         0.0772
# 1          0.0000      0.000      1.000      0.000           0         0.6808
# 2          0.1280      0.103      0.897      0.000           1         0.3182
# 3         -0.1027      0.000      0.887      0.113          -1        -0.7650
# 4          0.0000      0.000      1.000      0.000           0         0.5859
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.038     0.962     0.000          1
# 1     0.185     0.815     0.000          1
# 2     0.105     0.895     0.000          1
# 3     0.048     0.736     0.216         -1
# 4     0.124     0.876     0.000          1
#
#                                               tokens
# 0  [Back, in, September, Robinhood, announced, pl...
# 1  [British, entrepreneur, and, financier, Richar...
# 2  [El, Salvador, introduced, Bitcoin, a, a, lega...
# 3  [On, Tuesday, Ilya, Lichtenstein, and, Heather...
# 4  [Even, if, you, arent, paying, attention, to, ...

# %%
# Complete the tokenizer function - Open Banking
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))

    # NEED TO FIX STOPWORDS
    # Remove the stopwords
    #words = list(filter(lambda t: t.lower() not in stop, words))
    
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# Create a new tokens column for Bitcoin
openbanking_df["tokens"] = openbanking_df.text.apply(tokenizer)
openbanking_df.head()
# Out:
#                                                title  \
# 0  Indian shares open lower as IT, banks weigh - ...
# 1  Finicity co-founder talks open banking, fintec...
# 2  Plaid's Cognito deal helps it plan ahead for U...
# 3  Relationship banking can offer special perks, ...
# 4  Spruce banking review: Banking platform with c...
#
#                                          description  \
# 0  Indian shares edged lower on Friday, pressured...
# 1  Finicity CEO Steve Smith talks about how socia...
# 2  Open-banking provider Plaid has acquired Cogni...
# 3  Banks use relationship banking to build relati...
# 4  H&R Block has a new financial technology platf...
#
#                                                 text        date language  \
# 0  BENGALURU, Feb 18 (Reuters) - Indian shares ed...  2022-02-18       en
# 1  Although the UK pioneered open-\r\nbanking reg...  2022-02-04       en
# 2  The news: The \r\nopen-banking provider Plaid ...  2022-01-21       en
# 3  Relationship banking is a term you'll frequent...  2022-02-04       en
# 4  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.177      0.645      0.177           0         0.1779
# 1          0.5106      0.292      0.708      0.000           1         0.6705
# 2          0.3818      0.206      0.794      0.000           1         0.5859
# 3          0.4939      0.208      0.792      0.000           1         0.4588
# 4          0.4767      0.220      0.780      0.000           1         0.8360
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.127     0.765     0.108          1
# 1     0.151     0.849     0.000          1
# 2     0.156     0.844     0.000          1
# 3     0.091     0.909     0.000          1
# 4     0.268     0.732     0.000          1
#
#                                               tokens
# 0  [BENGALURU, Feb, 18, Reuters, Indian, share, e...
# 1  [Although, the, UK, pioneered, open-, banking,...
# 2  [The, news, The, open-banking, provider, Plaid...
# 3  [Relationship, banking, is, a, term, you, 'll,...
# 4  [The, bottom, line, Spruce, is, a, solid, mobi...

# %%
# Complete the tokenizer function - Banking
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    
    # NEED TO FIX STOPWORDS
    # Remove the stopwords
    #words = list(filter(lambda t: t.lower() not in stop, words))
    
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# Create a new tokens column for Bitcoin
banking_df["tokens"] = banking_df.text.apply(tokenizer)
banking_df.head()
# Out:
#                                                title  \
# 0                     The Banking CMO Report Preview
# 1  Spruce banking review: Banking platform with c...
# 2  India shares gain on energy, banking boost - R...
# 3    LIVE MARKETS Banking on banks in 2022 - Reuters
# 4  Australian shares weighed down by banking, hea...
#
#                                          description  \
# 0  Get an exclusive preview of the Banking CMO Re...
# 1  H&R Block has a new financial technology platf...
# 2  Indian shares rose on Friday, lifted by energy...
# 3  Welcome to the home for real-time coverage of ...
# 4  Australian shares slipped on Monday, as losses...
#
#                                                 text        date language  \
# 0  Our Banking CMO Report synthesizes interviews ...  2022-02-08       en
# 1  The bottom line:Spruce is a solid \r\nmobile b...  2022-01-21       en
# 2  BENGALURU, Jan 28 (Reuters) - Indian shares ro...  2022-01-28       en
# 3  Jan 25 - Welcome to the home for real-time cov...  2022-01-25       en
# 4  Feb 7 (Reuters) - Australian shares slipped on...  2022-02-07       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000        0.0           0         0.7620
# 1          0.4767      0.220      0.780        0.0           1         0.8360
# 2          0.8555      0.722      0.278        0.0           1         0.7650
# 3          0.0000      0.000      1.000        0.0           0         0.6369
# 4          0.2960      0.216      0.784        0.0           1         0.6808
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.191     0.809     0.000          1
# 1     0.268     0.732     0.000          1
# 2     0.213     0.787     0.000          1
# 3     0.144     0.856     0.000          1
# 4     0.227     0.707     0.066          1
#
#                                               tokens
# 0  [Our, Banking, CMO, Report, synthesizes, inter...
# 1  [The, bottom, line, Spruce, is, a, solid, mobi...
# 2  [BENGALURU, Jan, 28, Reuters, Indian, share, r...
# 3  [Jan, 25, Welcome, to, the, home, for, real-ti...
# 4  [Feb, 7, Reuters, Australian, share, slipped, ...

# %%
# Stop words
# NLTK list of stopwords
print(stopwords.words('english'))

languages = ['arabic', 'azerbaijani', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek','hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

for lang in languages:
    print("stopwords in:", lang, ":", len(stopwords.words(lang)))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# stopwords in: arabic : 754
# stopwords in: azerbaijani : 165
# stopwords in: danish : 94
# stopwords in: dutch : 101
# stopwords in: english : 179
# stopwords in: finnish : 235
# stopwords in: french : 157
# stopwords in: german : 232
# stopwords in: greek : 265
# stopwords in: hungarian : 199
# stopwords in: indonesian : 758
# stopwords in: italian : 279
# stopwords in: kazakh : 324
# stopwords in: nepali : 255
# stopwords in: norwegian : 176
# stopwords in: portuguese : 204
# stopwords in: romanian : 356
# stopwords in: russian : 151
# stopwords in: slovene : 1784
# stopwords in: spanish : 313
# stopwords in: swedish : 114
# stopwords in: tajik : 163
# stopwords in: turkish : 53

# %%
# Add Stop Words - NEED TO FIX
#sw = set(stopwords.words('english'))
#first_result = [word.lower() for word in words if word.lower() not in sw]
#sw_addon = {'id', 'none', 'name', 'reuters', 'source', 'author', 'title', 'business', 'content'}
#second_result = [word.lower() for word in words if word.lower() not in sw.union(sw_addon)]

# %% [markdown]
# ## NGrams and Frequency Analysis

# %%
# Generate the Crypto N-grams where N=2
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(crypto_news))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output

# %%
processed = process_text(article)
print(processed)
# Out:
# ['status', 'ok', 'totalresults', 'articles', 'source', 'id', 'engadget', 'name', 'engadget', 'author', 'igor', 'bonifacic', 'title', 'robinhood', 'opens', 'cryptocurrency', 'wallet', 'beta', 'testers', 'description', 'back', 'septemberrn', 'robinhood', 'announced', 'plans', 'test', 'cryptocurrency', 'wallet', 'within', 'app', 'time', 'company', 'said', 'would', 'open', 'beta', 'small', 'number', 'people', 'expanding', 'availability', 'ahead', 'fullscale', 'release', 'joined', 'wait', 'url', 'httpswwwengadgetcomrobinhoodcryptocurrencywalletbetahtml', 'urltoimage', 'httpssyimgcomoscreatruploadedimagesfefbdecbeaeb', 'publishedat', 'tz', 'content', 'back', 'septemberrn', 'robinhood', 'announced', 'plans', 'test', 'cryptocurrency', 'wallet', 'within', 'app', 'time', 'company', 'said', 'would', 'open', 'beta', 'small', 'number', 'people', 'expanding', 'availa', 'chars', 'source', 'id', 'wired', 'name', 'wired', 'author', 'gian', 'volpicelli', 'title', 'gibraltar', 'could', 'launch', 'worlds', 'first', 'crypto', 'stock', 'exchange', 'description', 'rock', 'hopes', 'new', 'stock', 'exchange', 'attract', 'crypto', 'millionaires', 'want', 'avoid', 'hefty', 'taxes', 'url', 'httpswwwwiredcomstorygibraltarcryptoexchange', 'urltoimage', 'httpsmediawiredcomphotosfbbffaefdwclimitbusinessgibraltarjpg', 'publishedat', 'tz', 'content', 'british', 'entrepreneur', 'financier', 'richard', 'odell', 'poulden', 'hopes', 'new', 'venture', 'relieve', 'plight', 'underserved', 'cohort', 'bitcoin', 'billionaires', 'want', 'buy', 'housernin', 'october', 'poulde', 'chars', 'source', 'id', 'theverge', 'name', 'verge', 'author', 'mitchell', 'clark', 'title', 'international', 'monetary', 'fund', 'tells', 'el', 'salvador', 'shouldnt', 'use', 'bitcoin', 'legal', 'tender', 'description', 'international', 'monetary', 'funds', 'executive', 'directors', 'recommended', 'el', 'salvador', 'narrow', 'scope', 'bitcoin', 'law', 'making', 'cryptocurrency', 'longer', 'legal', 'tender', 'country', 'url', 'httpswwwthevergecomelsalvadorbitcoininternationalmonetaryfundcrypto', 'urltoimage', 'httpscdnvoxcdncomthumboraltkknbnalupbavpijxmcugxxfitinxcdnvoxcdncomuploadschorusassetfileacastrobitcoinjpg', 'publishedat', 'tz', 'content', 'el', 'salvador', 'introduced', 'bitcoin', 'legal', 'tender', 'alongside', 'us', 'dollar', 'illustration', 'alex', 'castro', 'vergernn', 'nn', 'international', 'monetary', 'funds', 'executive', 'board', 'recommended', 'el', 'chars', 'source', 'id', 'wired', 'name', 'wired', 'author', 'andy', 'greenberg', 'title', 'dojs', 'b', 'seizure', 'shows', 'hard', 'launder', 'crypto', 'description', 'couple', 'allegedly', 'used', 'laundry', 'list', 'technical', 'measures', 'cover', 'tracks', 'didnt', 'matter', 'url', 'httpswwwwiredcomstorybitcoinseizurerecorddojcryptotracingmonero', 'urltoimage', 'httpsmediawiredcomphotoscdbafabwclimitsecuritycryptotracingjpg', 'publishedat', 'tz', 'content', 'tuesday', 'ilya', 'lichtenstein', 'heather', 'morgan', 'arrested', 'new', 'york', 'accused', 'laundering', 'record', 'billion', 'dollars', 'worth', 'stolen', 'cryptocurrency', 'hours', 'since', 'cybersecu', 'chars', 'source', 'id', 'none', 'name', 'lifehackercom', 'author', 'jeff', 'somers', 'title', 'crypto', 'bubble', 'going', 'burst', 'description', 'even', 'arent', 'paying', 'attention', 'bitcoin', 'cryptocurrencies', 'might', 'noticed', 'value', 'plummeted', 'last', 'week', 'total', 'value', 'market', 'tumbling', 'high', 'trillion', 'last', 'year', 'trillion', 'matter', 'days', 'url', 'httpslifehackercomisthecryptobubblegoingtoburst', 'urltoimage', 'httpsikinjaimgcomgawkermediaimageuploadcfillfautoflprogressivegcenterhpgqwabeeebdefjpg', 'publishedat', 'tz', 'content', 'even', 'arent', 'paying', 'attention', 'bitcoin', 'cryptocurrencies', 'might', 'noticed', 'value', 'plummeted', 'last', 'week', 'total', 'value', 'market', 'tumbling', 'high', 'tr', 'chars', 'source', 'id', 'wired', 'name', 'wired', 'author', 'gian', 'volpicelli', 'title', 'assanges', 'nft', 'clock', 'sal ...

# %%
crypto_bigram_counts = Counter(ngrams(processed, n=2))
print(dict(crypto_bigram_counts))
# Out:
# {('status', 'ok'): 1, ('ok', 'totalresults'): 1, ('totalresults', 'articles'): 1, ('articles', 'source'): 1, ('source', 'id'): 20, ('id', 'engadget'): 2, ('engadget', 'name'): 2, ('name', 'engadget'): 2, ('engadget', 'author'): 2, ('author', 'igor'): 1, ('igor', 'bonifacic'): 1, ('bonifacic', 'title'): 1, ('title', 'robinhood'): 1, ('robinhood', 'opens'): 1, ('opens', 'cryptocurrency'): 1, ('cryptocurrency', 'wallet'): 3, ('wallet', 'beta'): 1, ('beta', 'testers'): 1, ('testers', 'description'): 1, ('description', 'back'): 1, ('back', 'septemberrn'): 2, ('septemberrn', 'robinhood'): 2, ('robinhood', 'announced'): 2, ('announced', 'plans'): 2, ('plans', 'test'): 2, ('test', 'cryptocurrency'): 2, ('wallet', 'within'): 2, ('within', 'app'): 2, ('app', 'time'): 2, ('time', 'company'): 2, ('company', 'said'): 2, ('said', 'would'): 2, ('would', 'open'): 2, ('open', 'beta'): 2, ('beta', 'small'): 2, ('small', 'number'): 2, ('number', 'people'): 2, ('people', 'expanding'): 2, ('expanding', 'availability'): 1, ('availability', 'ahead'): 1, ('ahead', 'fullscale'): 1, ('fullscale', 'release'): 1, ('release', 'joined'): 1, ('joined', 'wait'): 1, ('wait', 'url'): 1, ('url', 'httpswwwengadgetcomrobinhoodcryptocurrencywalletbetahtml'): 1, ('httpswwwengadgetcomrobinhoodcryptocurrencywalletbetahtml', 'urltoimage'): 1, ('urltoimage', 'httpssyimgcomoscreatruploadedimagesfefbdecbeaeb'): 1, ('httpssyimgcomoscreatruploadedimagesfefbdecbeaeb', 'publishedat'): 1, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('content', 'back'): 1, ('expanding', 'availa'): 1, ('availa', 'chars'): 1, ('chars', 'source'): 19, ('id', 'wired'): 5, ('wired', 'name'): 5, ('name', 'wired'): 5, ('wired', 'author'): 5, ('author', 'gian'): 2, ('gian', 'volpicelli'): 2, ('volpicelli', 'title'): 2, ('title', 'gibraltar'): 1, ('gibraltar', 'could'): 1, ('could', 'launch'): 1, ('launch', 'worlds'): 1, ('worlds', 'first'): 1, ('first', 'crypto'): 1, ('crypto', 'stock'): 1, ('stock', 'exchange'): 2, ('exchange', 'description'): 1, ('description', 'rock'): 1, ('rock', 'hopes'): 1, ('hopes', 'new'): 2, ('new', 'stock'): 1, ('exchange', 'attract'): 1, ('attract', 'crypto'): 1, ('crypto', 'millionaires'): 1, ('millionaires', 'want'): 1, ('want', 'avoid'): 1, ('avoid', 'hefty'): 1, ('hefty', 'taxes'): 1, ('taxes', 'url'): 1, ('url', 'httpswwwwiredcomstorygibraltarcryptoexchange'): 1, ('httpswwwwiredcomstorygibraltarcryptoexchange', 'urltoimage'): 1, ('urltoimage', 'httpsmediawiredcomphotosfbbffaefdwclimitbusinessgibraltarjpg'): 1, ('httpsmediawiredcomphotosfbbffaefdwclimitbusinessgibraltarjpg', 'publishedat'): 1, ('content', 'british'): 1, ('british', 'entrepreneur'): 1, ('entrepreneur', 'financier'): 1, ('financier', 'richard'): 1, ('richard', 'odell'): 1, ('odell', 'poulden'): 1, ('poulden', 'hopes'): 1, ('new', 'venture'): 1, ('venture', 'relieve'): 1, ('relieve', 'plight'): 1, ('plight', 'underserved'): 1, ('underserved', 'cohort'): 1, ('cohort', 'bitcoin'): 1, ('bitcoin', 'billionaires'): 1, ('billionaires', 'want'): 1, ('want', 'buy'): 1, ('buy', 'housernin'): 1, ('housernin', 'october'): 1, ('october', 'poulde'): 1, ('poulde', 'chars'): 1, ('id', 'theverge'): 3, ('theverge', 'name'): 3, ('name', 'verge'): 3, ('verge', 'author'): 3, ('author', 'mitchell'): 1, ('mitchell', 'clark'): 1, ('clark', 'title'): 1, ('title', 'international'): 1, ('international', 'monetary'): 3, ('monetary', 'fund'): 1, ('fund', 'tells'): 1, ('tells', 'el'): 1, ('el', 'salvador'): 3, ('salvador', 'shouldnt'): 1, ('shouldnt', 'use'): 1, ('use', 'bitcoin'): 1, ('bitcoin', 'legal'): 2, ('legal', 'tender'): 3, ('tender', 'description'): 1, ('description', 'international'): 1, ('monetary', 'funds'): 2, ('funds', 'executive'): 2, ('executive', 'directors'): 1, ('directors', 'recommended'): 1, ('recommended', 'el'): 2, ('salvador', 'narrow'): 1, ('narrow', 'scope'): 1, ('scope', 'bitcoin'): 1, ('bitcoin', 'law'): 1, ('law', 'making'): 1, ('making', 'cryptocurrency'): 1, ('cryptocurrency', 'longer'): 1, ('long ...

# %%
# Generate the Open Banking N-grams where N=2
def process_text(article2):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(openbanking_news))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output

processed2 = process_text(article2)
print(processed2)

openbanking_bigram_counts = Counter(ngrams(processed2, n=2))
print(dict(openbanking_bigram_counts))
# Out:
# ['status', 'ok', 'totalresults', 'articles', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'indian', 'shares', 'open', 'lower', 'banks', 'weigh', 'reuters', 'india', 'description', 'indian', 'shares', 'edged', 'lower', 'friday', 'pressured', 'banking', 'stocks', 'investors', 'focused', 'eastwest', 'standoff', 'ukraine', 'roiled', 'markets', 'week', 'url', 'httpswwwreuterscomworldindiaindiansharesopenloweritbanksweigh', 'urltoimage', 'httpswwwreuterscomresizeroybgdnnloewvymeltnalmxsmartfiltersqualitycloudfrontuseastimagesarcpublishingcomreutersefgmtsyjpkjnytaahikvejpg', 'publishedat', 'tz', 'content', 'bengaluru', 'feb', 'reuters', 'indian', 'shares', 'edged', 'lower', 'friday', 'pressured', 'banking', 'stocks', 'investors', 'focused', 'eastwest', 'standoff', 'ukraine', 'roiled', 'markets', 'wee', 'chars', 'source', 'id', 'businessinsider', 'name', 'business', 'insider', 'author', 'insiderinsidercom', 'tyler', 'van', 'dyke', 'title', 'finicity', 'cofounder', 'talks', 'open', 'banking', 'fintech', 'trust', 'web', 'description', 'finicity', 'ceo', 'steve', 'smith', 'talks', 'social', 'media', 'companies', 'build', 'financial', 'trust', 'open', 'banking', 'web', 'url', 'httpswwwbusinessinsidercominterviewwithfinicityceostevesmithonopenbanking', 'urltoimage', 'httpsiinsidercomfdceafefewidthformatjpeg', 'publishedat', 'tz', 'content', 'although', 'ukxapioneeredxaopenrnbanking', 'regulations', 'popularized', 'termxafinicityxaceo', 'steve', 'smith', 'contends', 'us', 'long', 'engine', 'innovation', 'driving', 'space', 'forwardrnin', 'chars', 'source', 'id', 'businessinsider', 'name', 'business', 'insider', 'author', 'insiderinsidercom', 'tom', 'auchterlonie', 'title', 'plaids', 'cognito', 'deal', 'helps', 'plan', 'ahead', 'us', 'open', 'banking', 'description', 'openbanking', 'provider', 'plaid', 'acquired', 'cognito', 'fintech', 'offers', 'identity', 'verification', 'compliance', 'solutions', 'url', 'httpswwwbusinessinsidercomplaidacquirescognitoidentityverificationcompliancefintech', 'urltoimage', 'httpsiinsidercomeaceabffdfcewidthformatjpeg', 'publishedat', 'tz', 'content', 'newsxathe', 'rnopenbanking', 'providerxaplaidxahasrnxaacquiredrnxacognito', 'fintech', 'offers', 'identity', 'verification', 'compliance', 'solutionsrninsider', 'intelligencernmore', 'thisxain', 'blog', 'post', 'announc', 'chars', 'source', 'id', 'businessinsider', 'name', 'business', 'insider', 'author', 'sacevedoinsidercom', 'sophia', 'acevedo', 'title', 'relationship', 'banking', 'offer', 'special', 'perks', 'youll', 'open', 'several', 'bank', 'products', 'worth', 'description', 'banks', 'use', 'relationship', 'banking', 'build', 'relationships', 'customers', 'open', 'several', 'bank', 'accounts', 'bank', 'may', 'offer', 'better', 'rates', 'waive', 'fees', 'url', 'httpswwwbusinessinsidercompersonalfinancerelationshipbanking', 'urltoimage', 'httpsiinsidercomfdacafedwidthformatjpeg', 'publishedat', 'tz', 'content', 'relationship', 'banking', 'term', 'youll', 'frequently', 'find', 'many', 'brickandmortar', 'banks', 'national', 'banks', 'youre', 'looking', 'interest', 'rates', 'savings', 'account', 'might', 'see', 'relationship', 'rates', 'chars', 'source', 'id', 'businessinsider', 'name', 'business', 'insider', 'author', 'sacevedoinsidercom', 'sophia', 'acevedo', 'title', 'spruce', 'banking', 'review', 'banking', 'platform', 'cashback', 'rewards', 'early', 'direct', 'deposit', 'description', 'hr', 'block', 'new', 'financial', 'technology', 'platform', 'named', 'spruce', 'spruce', 'savings', 'spending', 'account', 'monthly', 'fees', 'url', 'httpswwwbusinessinsidercompersonalfinancesprucebankingreview', 'urltoimage', 'httpsiinsidercomedafcfbcwidthformatjpeg', 'publishedat', 'tz', 'content', 'bottom', 'linespruce', 'solid', 'rnmobile', 'banking', 'platform', 'doesnt', 'charge', 'monthly', 'fees', 'accounts', 'come', 'several', 'special', 'perks', 'like', 'cashback', 'rewards', 'early', 'direct', 'deposit', 'youll', 'want', 'chars', 'sour ...
# {('status', 'ok'): 1, ('ok', 'totalresults'): 1, ('totalresults', 'articles'): 1, ('articles', 'source'): 1, ('source', 'id'): 20, ('id', 'reuters'): 8, ('reuters', 'name'): 8, ('name', 'reuters'): 8, ('reuters', 'author'): 8, ('author', 'none'): 8, ('none', 'title'): 8, ('title', 'indian'): 1, ('indian', 'shares'): 3, ('shares', 'open'): 1, ('open', 'lower'): 1, ('lower', 'banks'): 1, ('banks', 'weigh'): 1, ('weigh', 'reuters'): 1, ('reuters', 'india'): 1, ('india', 'description'): 1, ('description', 'indian'): 1, ('shares', 'edged'): 2, ('edged', 'lower'): 2, ('lower', 'friday'): 2, ('friday', 'pressured'): 2, ('pressured', 'banking'): 2, ('banking', 'stocks'): 2, ('stocks', 'investors'): 2, ('investors', 'focused'): 2, ('focused', 'eastwest'): 2, ('eastwest', 'standoff'): 2, ('standoff', 'ukraine'): 2, ('ukraine', 'roiled'): 2, ('roiled', 'markets'): 2, ('markets', 'week'): 1, ('week', 'url'): 1, ('url', 'httpswwwreuterscomworldindiaindiansharesopenloweritbanksweigh'): 1, ('httpswwwreuterscomworldindiaindiansharesopenloweritbanksweigh', 'urltoimage'): 1, ('urltoimage', 'httpswwwreuterscomresizeroybgdnnloewvymeltnalmxsmartfiltersqualitycloudfrontuseastimagesarcpublishingcomreutersefgmtsyjpkjnytaahikvejpg'): 1, ('httpswwwreuterscomresizeroybgdnnloewvymeltnalmxsmartfiltersqualitycloudfrontuseastimagesarcpublishingcomreutersefgmtsyjpkjnytaahikvejpg', 'publishedat'): 1, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('content', 'bengaluru'): 1, ('bengaluru', 'feb'): 1, ('feb', 'reuters'): 6, ('reuters', 'indian'): 1, ('markets', 'wee'): 1, ('wee', 'chars'): 1, ('chars', 'source'): 19, ('id', 'businessinsider'): 7, ('businessinsider', 'name'): 7, ('name', 'business'): 7, ('business', 'insider'): 7, ('insider', 'author'): 7, ('author', 'insiderinsidercom'): 3, ('insiderinsidercom', 'tyler'): 1, ('tyler', 'van'): 1, ('van', 'dyke'): 1, ('dyke', 'title'): 1, ('title', 'finicity'): 1, ('finicity', 'cofounder'): 1, ('cofounder', 'talks'): 1, ('talks', 'open'): 1, ('open', 'banking'): 3, ('banking', 'fintech'): 1, ('fintech', 'trust'): 1, ('trust', 'web'): 1, ('web', 'description'): 1, ('description', 'finicity'): 1, ('finicity', 'ceo'): 1, ('ceo', 'steve'): 1, ('steve', 'smith'): 2, ('smith', 'talks'): 1, ('talks', 'social'): 1, ('social', 'media'): 1, ('media', 'companies'): 1, ('companies', 'build'): 1, ('build', 'financial'): 1, ('financial', 'trust'): 1, ('trust', 'open'): 1, ('banking', 'web'): 1, ('web', 'url'): 1, ('url', 'httpswwwbusinessinsidercominterviewwithfinicityceostevesmithonopenbanking'): 1, ('httpswwwbusinessinsidercominterviewwithfinicityceostevesmithonopenbanking', 'urltoimage'): 1, ('urltoimage', 'httpsiinsidercomfdceafefewidthformatjpeg'): 1, ('httpsiinsidercomfdceafefewidthformatjpeg', 'publishedat'): 1, ('content', 'although'): 1, ('although', 'ukxapioneeredxaopenrnbanking'): 1, ('ukxapioneeredxaopenrnbanking', 'regulations'): 1, ('regulations', 'popularized'): 1, ('popularized', 'termxafinicityxaceo'): 1, ('termxafinicityxaceo', 'steve'): 1, ('smith', 'contends'): 1, ('contends', 'us'): 1, ('us', 'long'): 1, ('long', 'engine'): 1, ('engine', 'innovation'): 1, ('innovation', 'driving'): 1, ('driving', 'space'): 1, ('space', 'forwardrnin'): 1, ('forwardrnin', 'chars'): 1, ('insiderinsidercom', 'tom'): 2, ('tom', 'auchterlonie'): 2, ('auchterlonie', 'title'): 2, ('title', 'plaids'): 1, ('plaids', 'cognito'): 1, ('cognito', 'deal'): 1, ('deal', 'helps'): 1, ('helps', 'plan'): 1, ('plan', 'ahead'): 1, ('ahead', 'us'): 1, ('us', 'open'): 1, ('banking', 'description'): 1, ('description', 'openbanking'): 1, ('openbanking', 'provider'): 1, ('provider', 'plaid'): 1, ('plaid', 'acquired'): 1, ('acquired', 'cognito'): 1, ('cognito', 'fintech'): 1, ('fintech', 'offers'): 2, ('offers', 'identity'): 2, ('identity', 'verification'): 2, ('verification', 'compliance'): 2, ('compliance', 'solutions'): 1, ('solutions', 'url'): 1, ('url', 'httpswwwbusinessinsidercomplaidacquirescognitoidentityverificationcompliancefintech'): 1, ...

# %%
# Generate the Banking N-grams where N=2
def process_text(article3):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(banking_news))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output

processed3 = process_text(article3)
print(processed3)

banking_bigram_counts = Counter(ngrams(processed3, n=2))
print(dict(banking_bigram_counts))
# Out:
# ['status', 'ok', 'totalresults', 'articles', 'source', 'id', 'none', 'name', 'insiderintelligencecom', 'author', 'insiderinsidercom', 'insider', 'intelligence', 'title', 'banking', 'cmo', 'report', 'preview', 'description', 'get', 'exclusive', 'preview', 'banking', 'cmo', 'report', 'start', 'receiving', 'financial', 'services', 'newsletter', 'insider', 'intelligence', 'daily', 'covers', 'todays', 'important', 'trends', 'banking', 'fintech', 'payments', 'url', 'httpswwwinsiderintelligencecomresourcesbankingcmopreview', 'urltoimage', 'httpswwwinsiderintelligencecomstaticiiwhiteonblackfbbeacdaaedbcfpng', 'publishedat', 'tz', 'content', 'banking', 'cmo', 'report', 'synthesizes', 'interviews', 'cmos', 'largest', 'innovative', 'banks', 'credit', 'unions', 'neobanks', 'us', 'canadarnthrough', 'exclusive', 'interviews', 'pr', 'chars', 'source', 'id', 'businessinsider', 'name', 'business', 'insider', 'author', 'sacevedoinsidercom', 'sophia', 'acevedo', 'title', 'spruce', 'banking', 'review', 'banking', 'platform', 'cashback', 'rewards', 'early', 'direct', 'deposit', 'description', 'hr', 'block', 'new', 'financial', 'technology', 'platform', 'named', 'spruce', 'spruce', 'savings', 'spending', 'account', 'monthly', 'fees', 'url', 'httpswwwbusinessinsidercompersonalfinancesprucebankingreview', 'urltoimage', 'httpsiinsidercomedafcfbcwidthformatjpeg', 'publishedat', 'tz', 'content', 'bottom', 'linespruce', 'solid', 'rnmobile', 'banking', 'platform', 'doesnt', 'charge', 'monthly', 'fees', 'accounts', 'come', 'several', 'special', 'perks', 'like', 'cashback', 'rewards', 'early', 'direct', 'deposit', 'youll', 'want', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'india', 'shares', 'gain', 'energy', 'banking', 'boost', 'reuters', 'description', 'indian', 'shares', 'rose', 'friday', 'lifted', 'energy', 'banking', 'stocks', 'amid', 'strong', 'earnings', 'momentum', 'slight', 'rebound', 'global', 'markets', 'also', 'aided', 'investor', 'sentiment', 'url', 'httpswwwreuterscomworldindiaindiasharesgainenergybankingboost', 'urltoimage', 'httpswwwreuterscomresizeroybgdnnloewvymeltnalmxsmartfiltersqualitycloudfrontuseastimagesarcpublishingcomreutersefgmtsyjpkjnytaahikvejpg', 'publishedat', 'tz', 'content', 'bengaluru', 'jan', 'reuters', 'indian', 'shares', 'rose', 'friday', 'lifted', 'energy', 'banking', 'stocks', 'amid', 'strong', 'earnings', 'momentum', 'slight', 'rebound', 'global', 'markets', 'also', 'aided', 'investor', 'sentimentr', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'live', 'markets', 'banking', 'banks', 'reuters', 'description', 'welcome', 'home', 'realtime', 'coverage', 'markets', 'brought', 'reuters', 'reporters', 'share', 'thoughts', 'us', 'hrefmailtomarketsresearchthomsonreuterscom', 'targetblankmarketsresearchthomsonreuterscoma', 'url', 'httpswwwreuterscommarketsasialivemarketsbankingbanks', 'urltoimage', 'httpswwwreuterscompfresourcesimagesreutersreutersdefaultpngd', 'publishedat', 'tz', 'content', 'jan', 'welcome', 'home', 'realtime', 'coverage', 'markets', 'brought', 'reuters', 'reporters', 'share', 'thoughts', 'us', 'marketsresearchthomsonreuterscomrnbanking', 'banks', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'australian', 'shares', 'weighed', 'banking', 'healthcare', 'stocks', 'reuters', 'description', 'australian', 'shares', 'slipped', 'monday', 'losses', 'banking', 'healthcare', 'sectors', 'offset', 'gains', 'made', 'energy', 'mining', 'firms', 'travel', 'stocks', 'gained', 'country', 'geared', 'reopen', 'borders', 'vaccinated', 'tourists', 'later', 'month', 'url', 'httpswwwreuterscommarketsstocksaustraliansharesweigheddownbybankinghealthcarestocks', 'urltoimage', 'httpswwwreuterscompfresourcesimagesreutersreutersdefaultpngd', 'publishedat', 'tz', 'content', 'feb', 'reuters', 'australian', 'shares', 'slipped', 'monday', 'losses', 'banking', 'healthcare', 'sectors', 'offset', 'gains', 'made', 'energy', 'mining',  ...
# {('status', 'ok'): 1, ('ok', 'totalresults'): 1, ('totalresults', 'articles'): 1, ('articles', 'source'): 1, ('source', 'id'): 20, ('id', 'none'): 3, ('none', 'name'): 3, ('name', 'insiderintelligencecom'): 1, ('insiderintelligencecom', 'author'): 1, ('author', 'insiderinsidercom'): 5, ('insiderinsidercom', 'insider'): 1, ('insider', 'intelligence'): 2, ('intelligence', 'title'): 1, ('title', 'banking'): 2, ('banking', 'cmo'): 3, ('cmo', 'report'): 3, ('report', 'preview'): 1, ('preview', 'description'): 1, ('description', 'get'): 1, ('get', 'exclusive'): 1, ('exclusive', 'preview'): 1, ('preview', 'banking'): 1, ('report', 'start'): 1, ('start', 'receiving'): 1, ('receiving', 'financial'): 1, ('financial', 'services'): 1, ('services', 'newsletter'): 1, ('newsletter', 'insider'): 1, ('intelligence', 'daily'): 1, ('daily', 'covers'): 1, ('covers', 'todays'): 1, ('todays', 'important'): 1, ('important', 'trends'): 1, ('trends', 'banking'): 1, ('banking', 'fintech'): 2, ('fintech', 'payments'): 1, ('payments', 'url'): 1, ('url', 'httpswwwinsiderintelligencecomresourcesbankingcmopreview'): 1, ('httpswwwinsiderintelligencecomresourcesbankingcmopreview', 'urltoimage'): 1, ('urltoimage', 'httpswwwinsiderintelligencecomstaticiiwhiteonblackfbbeacdaaedbcfpng'): 1, ('httpswwwinsiderintelligencecomstaticiiwhiteonblackfbbeacdaaedbcfpng', 'publishedat'): 1, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('content', 'banking'): 1, ('report', 'synthesizes'): 1, ('synthesizes', 'interviews'): 1, ('interviews', 'cmos'): 1, ('cmos', 'largest'): 1, ('largest', 'innovative'): 1, ('innovative', 'banks'): 1, ('banks', 'credit'): 1, ('credit', 'unions'): 1, ('unions', 'neobanks'): 1, ('neobanks', 'us'): 1, ('us', 'canadarnthrough'): 1, ('canadarnthrough', 'exclusive'): 1, ('exclusive', 'interviews'): 1, ('interviews', 'pr'): 1, ('pr', 'chars'): 1, ('chars', 'source'): 19, ('id', 'businessinsider'): 5, ('businessinsider', 'name'): 5, ('name', 'business'): 5, ('business', 'insider'): 5, ('insider', 'author'): 5, ('author', 'sacevedoinsidercom'): 1, ('sacevedoinsidercom', 'sophia'): 1, ('sophia', 'acevedo'): 1, ('acevedo', 'title'): 1, ('title', 'spruce'): 1, ('spruce', 'banking'): 1, ('banking', 'review'): 1, ('review', 'banking'): 1, ('banking', 'platform'): 2, ('platform', 'cashback'): 1, ('cashback', 'rewards'): 2, ('rewards', 'early'): 2, ('early', 'direct'): 2, ('direct', 'deposit'): 2, ('deposit', 'description'): 1, ('description', 'hr'): 1, ('hr', 'block'): 1, ('block', 'new'): 1, ('new', 'financial'): 1, ('financial', 'technology'): 1, ('technology', 'platform'): 1, ('platform', 'named'): 1, ('named', 'spruce'): 1, ('spruce', 'spruce'): 1, ('spruce', 'savings'): 1, ('savings', 'spending'): 1, ('spending', 'account'): 1, ('account', 'monthly'): 1, ('monthly', 'fees'): 2, ('fees', 'url'): 1, ('url', 'httpswwwbusinessinsidercompersonalfinancesprucebankingreview'): 1, ('httpswwwbusinessinsidercompersonalfinancesprucebankingreview', 'urltoimage'): 1, ('urltoimage', 'httpsiinsidercomedafcfbcwidthformatjpeg'): 1, ('httpsiinsidercomedafcfbcwidthformatjpeg', 'publishedat'): 1, ('content', 'bottom'): 1, ('bottom', 'linespruce'): 1, ('linespruce', 'solid'): 1, ('solid', 'rnmobile'): 1, ('rnmobile', 'banking'): 1, ('platform', 'doesnt'): 1, ('doesnt', 'charge'): 1, ('charge', 'monthly'): 1, ('fees', 'accounts'): 1, ('accounts', 'come'): 1, ('come', 'several'): 1, ('several', 'special'): 1, ('special', 'perks'): 1, ('perks', 'like'): 1, ('like', 'cashback'): 1, ('deposit', 'youll'): 1, ('youll', 'want'): 1, ('want', 'chars'): 1, ('id', 'reuters'): 11, ('reuters', 'name'): 11, ('name', 'reuters'): 11, ('reuters', 'author'): 11, ('author', 'none'): 11, ('none', 'title'): 11, ('title', 'india'): 1, ('india', 'shares'): 1, ('shares', 'gain'): 1, ('gain', 'energy'): 1, ('energy', 'banking'): 3, ('banking', 'boost'): 1, ('boost', 'reuters'): 1, ('reuters', 'description'): 10, ('description', 'indian'): 3, ('indian', 'shares'): 8, ('shares', 'rose'): 2, ('rose' ...

# %%
# Function token_count generates the top 10 words for a given concept
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Crypto
print(dict(crypto_bigram_counts.most_common(10)))
# Out:
# {('source', 'id'): 20, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('chars', 'source'): 19, ('heather', 'morgan'): 7, ('id', 'none'): 7, ('none', 'name'): 7, ('ilya', 'lichtenstein'): 6, ('new', 'york'): 6, ('id', 'wired'): 5}

# %%
# Use token_count to get the top 10 words for Open Banking
print(dict(openbanking_bigram_counts.most_common(10)))
# Out:
# {('source', 'id'): 20, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('chars', 'source'): 19, ('id', 'reuters'): 8, ('reuters', 'name'): 8, ('name', 'reuters'): 8, ('reuters', 'author'): 8, ('author', 'none'): 8, ('none', 'title'): 8}

# %%
# Use token_count to get the top 10 words for Banking
print(dict(banking_bigram_counts.most_common(10)))
# Out:
# {('source', 'id'): 20, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('chars', 'source'): 19, ('id', 'reuters'): 11, ('reuters', 'name'): 11, ('name', 'reuters'): 11, ('reuters', 'author'): 11, ('author', 'none'): 11, ('none', 'title'): 11}

# %%
# Generate the Crypto word cloud
wc = WordCloud().generate(' '.join(processed))
plt.imshow(wc)

# %%
# Generate the Crypto word cloud
wc = WordCloud().generate(' '.join(processed2))
plt.imshow(wc)

# %%
# Generate the Crypto word cloud
wc = WordCloud().generate(' '.join(processed3))
plt.imshow(wc)
