# %%
# Import Libraries
import pandas as pd
from collections import OrderedDict
import requests
import boto3 
comprehend = boto3.client('comprehend', region_name='us-west-2')

# %%
# Point to Bucket and File
bucket_crypto = "p3-crypto"
data_key = "project3crypto.txt"
data_location = 's3://{}/{}'.format(bucket_crypto, data_key)

# %%
# Create S3 Client and get the object using bucket name and object key
s3_client = boto3.client('s3')
obj = s3_client.get_object(Bucket=bucket_crypto, Key=data_key)

# Read Object Content
contents = obj['Body'].read()
# print(contents.decode("latin"))
crypto_txt = contents.decode("latin")
crypto_txt
# Out:
# '[\'British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\\r\\nIn October, Poulde\x85 [+3364 chars]\', \'El Salvador introduced Bitcoin as a legal tender alongside the US dollar in 2021. | Illustration by Alex Castro / The Verge\\r\\n\\n \\n\\n The International Monetary Fund\x92s executive board has recommended El \x85 [+2691 chars]\', \'On Tuesday, Ilya Lichtenstein and Heather Morgan were arrested in New York and accused of laundering a record $4.5 billion dollars worth of stolen cryptocurrency. In the 24 hours since, the cybersecu\x85 [+4297 chars]\', \'Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 tr\x85 [+4782 chars]\', \'On February 3, the group started accepting ether donations on crypto crowdfunding pla
# ...

# %%
# Key phrases
phrases = comprehend.detect_key_phrases(Text=crypto_txt, LanguageCode='en')

# Entities
entities = comprehend.detect_entities(Text=crypto_txt, LanguageCode='en')

#Sentiments
sentiments = comprehend.detect_sentiment(Text=crypto_txt, LanguageCode='en')

# %%
# Print the phrases:
print('------- phrases ---------')
for i in range(0, len(phrases['KeyPhrases'])):
    print((phrases['KeyPhrases'][i]['Text']))
# Out:
# ------- phrases ---------
# 'British entrepreneur and financier Richard ODell Poulden
# his new venture
# the plight
# an underserved cohort
# Bitcoin billionaires
# a house
# October
# Poulde [+3364 chars
# El Salvador
# Bitcoin
# a legal tender
# the US dollar
# 2021
# | Illustration
# Alex Castro / The Verge\r\n\n
# The International Monetary Funds
# executive board
# El  [+2691 chars]
# Tuesday
# Ilya Lichtenstein and
# Heather Morgan
# New York
# a record
# $4.5 billion dollars
# stolen cryptocurrency
# the 24 hours
# the cybersecu [+4297 chars
# attention
# Bitcoin
# other cryptocurrencies
# their value
# last week
# the total value
# the market
# a high
# $3 tr [+4782 chars]
# February 3
# the group
# ether donations
# crypto crowdfunding platform Juicebox
# some $52 million
# exchange
# their contributions
# all donors
# cryp [+3219 chars]
# This Sunday
# the Los Angeles Rams
# the Cincinnati Bengals
# Super Bowl LVI
# the game
# about more than just sports
# the adverts
# ...

# %%
# Print the entities with entitity type:
print('------- entity : entity type ---------')
for i in range(0, len(entities['Entities'])):
    print(entities['Entities'][i]['Text'] + ' : ' + entities['Entities'][i]['Type'])
# Out:
# ------- entity : entity type ---------
# British : OTHER
# Richard ODell Poulden : PERSON
# October : DATE
# Poulde : PERSON
# +3364 chars : QUANTITY
# El Salvador : ORGANIZATION
# US : LOCATION
# 2021 : DATE
# Alex Castro : PERSON
# The Verge : ORGANIZATION
# International Monetary Funds : ORGANIZATION
# El : PERSON
# +2691 chars : QUANTITY
# Tuesday : DATE
# Ilya Lichtenstein : PERSON
# Heather Morgan : PERSON
# New York : LOCATION
# $4.5 billion dollars : QUANTITY
# 24 hours : QUANTITY
# +4297 chars : QUANTITY
# Bitcoin : OTHER
# last week : DATE
# $3 tr : QUANTITY
# +4782 chars : QUANTITY
# February 3 : DATE
# Juicebox : ORGANIZATION
# $52 million : QUANTITY
# +3219 chars : QUANTITY
# This Sunday : DATE
# Los Angeles Rams : ORGANIZATION
# Cincinnati Bengals : ORGANIZATION
# Super Bowl LVI : EVENT
# +228 chars : QUANTITY
# SOL : ORGANIZATION
# Tuesday : DATE
# each SOL : QUANTITY
# about $95. : QUANTITY
# +876 chars : QUANTITY
# +3031 chars : QUANTITY
# couple : QUANTITY
# ...

# %%
# Print the sentiment:
print('------- sentiment ---------')
print(sentiments['Sentiment'])
# Out:
# ------- sentiment ---------
# NEUTRAL
